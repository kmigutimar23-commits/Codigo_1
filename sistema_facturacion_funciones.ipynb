# %% [markdown]
# # 🧾 Papelería El Lápiz Feliz — el menú convertido en funciones
# ### S10 · Funciones · Lenguajes de Programación (FDE 058)
#
# Hoy tomamos el menú que ya escribimos y lo partimos en **funciones sencillas**.
# Cada función hace **una sola cosa** y el menú solo la llama.
#
# **Cómo se trabaja:**
# 1. Ejecuta las celdas en orden (Shift + Enter).
# 2. Donde diga `# ✏️ TU CÓDIGO AQUÍ`, escribes tú.
# 3. Al final, ejecuta el menú y pruébalo.

# %% [markdown]
# ## 📦 Los datos (ya vienen listos)
# Un diccionario para los productos y otro para los clientes.

# %%
catalogo = {
    "C-010": {"nombre": "Cuaderno cuadriculado 100 hojas", "precio": 7500,  "iva": 0.19},
    "L-020": {"nombre": "Lápiz negro N.2",                 "precio": 1200,  "iva": 0.19},
    "B-030": {"nombre": "Libro escolar de matemáticas",     "precio": 45000, "iva": 0.00},
}

clientes = {
    "900123": {"nombre": "Colegio San Jose",     "tipo": "colegio"},
    "100987": {"nombre": "Laura Restrepo",       "tipo": "detal"},
    "900456": {"nombre": "Oficina Contadores SAS","tipo": "oficina"},
}

print("Productos:", len(catalogo), "· Clientes:", len(clientes))
# Out:
# Productos: 3 · Clientes: 3

# %% [markdown]
# ## 🎁 Cómo se lee una función
#
# ```
# def  nombre_de_la_funcion(parametros):   ← qué recibe
#      """Qué hace"""                     ← documentación
#      ...cuerpo...                        ← qué hace
#      return resultado                    ← qué devuelve (opcional)
# ```
# Una función que solo **muestra** información no necesita `return`.

# %% [markdown]
# ## 📖 Misión 1 · `ver_catalogo()`
#
# Convierte el diccionario del catálogo en una función que lo muestre.
# No recibe nada, no devuelve nada: solo imprime.

# %%
def ver_catalogo():
    """Muestra todos los productos del catálogo."""
    print("CATÁLOGO DE PRODUCTOS")
    # ✏️ TU CÓDIGO AQUÍ: recorre catalogo.items() e imprime código, nombre y precio
    for codigo, info in catalogo.items():
        print(f"  {codigo} - {info['nombre']} (Precio: ${info['precio']:.2f})")


ver_catalogo()
# Out:
# CATÁLOGO DE PRODUCTOS
#   C-010 - Cuaderno cuadriculado 100 hojas (Precio: $7500.00)
#   L-020 - Lápiz negro N.2 (Precio: $1200.00)
#   B-030 - Libro escolar de matemáticas (Precio: $45000.00)

# %% [markdown]
# ## ➕ Misión 2 · `agregar_producto()`
#
# Recibe código, nombre y precio, y guarda el producto en el catálogo.
# Recuerda: `catalogo[codigo] = {...}` agrega una llave nueva al diccionario.

# %%
def agregar_producto(codigo, nombre, precio):
    """Agrega un producto nuevo al catálogo."""
    # ✏️ TU CÓDIGO AQUÍ: guarda el producto y avisa con un print
    catalogo[codigo] = {"nombre": nombre, "precio": precio, "iva": 0.19} # Asumiendo un IVA por defecto como en otros productos.
    print(f"Producto '{nombre}' (código {codigo}) agregado al catálogo.")


agregar_producto("T-040", "Memoria USB 32 GB", 38000)
ver_catalogo()
# Out:
# Producto 'Memoria USB 32 GB' (código T-040) agregado al catálogo.
# CATÁLOGO DE PRODUCTOS
#   C-010 - Cuaderno cuadriculado 100 hojas (Precio: $7500.00)
#   L-020 - Lápiz negro N.2 (Precio: $1200.00)
#   B-030 - Libro escolar de matemáticas (Precio: $45000.00)
#   T-040 - Memoria USB 32 GB (Precio: $38000.00)

# %% [markdown]
# ## 👥 Misión 3 · `ver_clientes()`
#
# La misma idea de la misión 1, pero con el diccionario de clientes.

# %%
def ver_clientes():
    """Muestra todos los clientes registrados."""
    # ✏️ TU CÓDIGO AQUÍ: recorre clientes.items() e imprime documento, nombre y tipo
    print("LISTA DE CLIENTES")
    for documento, info in clientes.items():
        print(f"  {documento} - {info['nombre']} (Tipo: {info['tipo']})")


ver_clientes()
# Out:
# LISTA DE CLIENTES
#   900123 - Colegio San Jose (Tipo: colegio)
#   100987 - Laura Restrepo (Tipo: detal)
#   900456 - Oficina Contadores SAS (Tipo: oficina)

# %% [markdown]
# ## 🗑️ Misión 4 · `eliminar_cliente()`
#
# Recibe el documento y borra ese cliente con `del clientes[documento]`.
# Antes de borrar, revisa con un `if` que exista, para que el programa no se caiga.

# %%
def eliminar_cliente(documento):
    """Elimina un cliente si existe."""
    # ✏️ TU CÓDIGO AQUÍ: if documento in clientes: ... else: avisa
    if documento in clientes:
        del clientes[documento]
        print(f"Cliente con documento {documento} eliminado exitosamente.")
    else:
        print(f"Error: No se encontró ningún cliente con el documento {documento}.")


eliminar_cliente("900456")
ver_clientes()
# Out:
# Cliente con documento 900456 eliminado exitosamente.
# LISTA DE CLIENTES
#   900123 - Colegio San Jose (Tipo: colegio)
#   100987 - Laura Restrepo (Tipo: detal)

# %% [markdown]
# ## 🔍 Misión 5 · `consultar()`
#
# Recibe un dato y lo busca primero en productos y luego en clientes.
# Si no está en ninguno, avisa que no lo encontró.

# %%
def consultar(dato):
    """Busca el dato en productos o en clientes."""
    # ✅ TU CÓDIGO AQUÍ
    if dato in catalogo:
        info = catalogo[dato]
        print(f"Producto encontrado: {info['nombre']} (Precio: ${info['precio']:.2f})")
    elif dato in clientes:
        info = clientes[dato]
        print(f"Cliente encontrado: {info['nombre']} (Tipo: {info['tipo']})")
    else:
        print(f"El dato '{dato}' no se encontró en el catálogo ni en clientes.")


consultar("C-010")
consultar("900123")
consultar("XXX")
# Out:
# Producto encontrado: Cuaderno cuadriculado 100 hojas (Precio: $7500.00)
# Cliente encontrado: Colegio San Jose (Tipo: colegio)
# El dato 'XXX' no se encontró en el catálogo ni en clientes.

# %% [markdown]
# ## 🖥️ Misión 6 · `menu()` — la integradora
#
# Aquí se juntan todas tus funciones. El menú ya no hace el trabajo: solo **dibuja las opciones**, pregunta y **llama** a la función correspondiente.
#
# Así se verá en pantalla:
# ```
# ================================
#    EL LÁPIZ FELIZ · CAJA
# ================================
#    1. Ver catálogo
#    2. Agregar producto
#    3. Ver clientes
#    4. Consultar
#    5. Salir
# ```

# %%
def menu():
    """Menú de la caja: solo coordina, no calcula."""
    opcion = ""
    while opcion != "5":
        print("=" * 32)
        print("   EL LÁPIZ FELIZ · CAJA")
        print("=" * 32)
        print("   1. Ver catálogo")
        print("   2. Agregar producto")
        print("   3. Ver clientes")
        print("   4. Consultar")
        print("   5. Salir")
        opcion = input("   Opción: ")

        # ✅ TU CÓDIGO AQUÍ
        if opcion == "1":
            ver_catalogo()
        elif opcion == "2":
            codigo = input("Ingrese el código del producto: ")
            nombre = input("Ingrese el nombre del producto: ")
            precio = float(input("Ingrese el precio del producto: "))
            agregar_producto(codigo, nombre, precio)
        elif opcion == "3":
            ver_clientes()
        elif opcion == "4":
            dato = input("Ingrese el código de producto o documento del cliente a consultar: ")
            consultar(dato)
        elif opcion == "5":
            print("¡Hasta pronto!")
        else:
            print("Opción no válida. Por favor, intente de nuevo.")


menu()
# Out:
# ...
#    EL LÁPIZ FELIZ · CAJA
# ...
#    1. Ver catálogo
#    2. Agregar producto
#    3. Ver clientes
#    4. Consultar
#    5. Salir
#    Opción: 1
# CATÁLOGO DE PRODUCTOS
#   C-010 - Cuaderno cuadriculado 100 hojas (Precio: $7500.00)
#   L-020 - Lápiz negro N.2 (Precio: $1200.00)
#   B-030 - Libro escolar de matemáticas (Precio: $45000.00)
#   T-040 - Memoria USB 32 GB (Precio: $38000.00)
# ...
#    EL LÁPIZ FELIZ · CAJA
# ...
#    1. Ver catálogo
#    2. Agregar producto
#    3. Ver clientes
#    4. Consultar
#    5. Salir
#    Opción: 3
# LISTA DE CLIENTES
#   900123 - Colegio San Jose (Tipo: colegio)
#   100987 - Laura Restrepo (Tipo: detal)
# ...
#    EL LÁPIZ FELIZ · CAJA
# ...
#    1. Ver catálogo
#    2. Agregar producto
#    3. Ver clientes
#    4. Consultar
#    5. Salir

# %% [markdown]
# ## ✅ Revisión
# Ejecuta esta celda: te dice qué funciones ya existen.

# %%
for f in ["ver_catalogo", "agregar_producto", "ver_clientes", "eliminar_cliente", "consultar", "menu"]:
    print("✅" if f in globals() else "❌", f)

# %% [markdown]
# ## 📤 Qué entregas
# 1. Archivo ▸ Descargar ▸ `.ipynb`.
# 2. Súbelo a tu repositorio de GitHub.
# 3. Pega el enlace en la plataforma.
